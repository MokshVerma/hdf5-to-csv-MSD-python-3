# %%
from musixmatch import Musixmatch
import urllib,json

# %%
musixmatch=Musixmatch('e5e7719b47f96c02f10ecc01d2025414')

# %%
musixmatch.chart_artists(1, 100, country='in')
# Out:
# {'message': {'header': {'status_code': 200, 'execute_time': 0.11931705474854},
#   'body': {'artist_list': [{'artist': {'artist_id': 24900845,
#       'artist_mbid': '00fc05b6-4a0d-4e0e-be4c-2cd4b94ce1e9',
#       'artist_name': 'Sid Sriram',
#       'artist_name_translation_list': [],
#       'artist_comment': '',
#       'artist_country': '',
#       'artist_alias_list': [],
#       'artist_rating': 43,
#       'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1264,
#           'music_genre_parent_id': 1262,
#           'music_genre_name': 'Tamil',
#           'music_genre_name_extended': 'Indian / Tamil',
#           'music_genre_vanity': 'Indian-Tamil'}},
#         {'music_genre': {'music_genre_id': 1265,
#           'music_genre_parent_id': 1262,
#           'music_genre_name': 'Telugu',
#           'music_genre_name_extended': 'Indian / Telugu',
#           'music_genre_vanity': 'Indian-Telugu'}}]},
#       'secondary_genres': {'music_genre_list': []},
# ...

# %%
musixmatch.track_search('Havana', 'Camila Cabello',1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-fd8ffdb4709c> in <module>()
# ----> 1 musixmatch.track_search('Havana', 'Camila Cabello',1)
#
# TypeError: track_search() missing 2 required positional arguments: 'page' and 's_track_rating'

# %%
data = musixmatch.chart_tracks_get(1, 1, 1)

# %%
data

# %%
dict = {'hello': {'bye':34528974928347}, 'dgdg': 234234}
dict

# %%
dict['hello']['bye']

# %%
id = data['message']['body']['track_list'][0]['track']['track_id']

# %%
lyricsbs = musixmatch.track_lyrics_get(id)
lyricsbs

# %%
lyrics = lyricsbs['message']['body']['lyrics']['lyrics_body']
lyrics

# %%
type(lyrics)

# %%
 musixmatch.track_search(q_track='rosie', q_artist='johnmayer', page_size=1, page=1, s_track_rating='asc')

# %%
musixmatch.track_search(q_track='stressedout',q_artist='twentyonepilots', page_size=10, page=1, s_track_rating='desc')

# %%
data1 =musixmatch.matcher_track_get('havana','camilacabelloyoungthug')
data1

# %%
id = data1['message']['body']['track']['track_id']
id

# %%
lyricsbs = musixmatch.track_lyrics_get(id)
lyricsbs

# %%
lyrics = lyricsbs['message']['body']['lyrics']['lyrics_body']
lyrics

# %%
data = musixmatch.matcher_lyrics_get('Havana','Camila Cabelloyoung thug')
data
# Out:
# {'message': {'header': {'status_code': 200,
#    'execute_time': 0.0082089900970459},
#   'body': {'lyrics': {'lyrics_id': 17861407,
#     'can_edit': 0,
#     'locked': 0,
#     'published_status': 5,
#     'action_requested': '',
#     'verified': 0,
#     'restricted': 0,
#     'instrumental': 0,
#     'explicit': 1,
# ...

# %%
data['message']['body']['lyrics']['lyrics_body']
# Out:
# 'Hey\n\nHavana, ooh na-na (ayy)\nHalf of my heart is in Havana, ooh na-na (ayy, ayy)\nHe took me back to East Atlanta, na-na-na, ah\nAll of my heart is in Havana (ayy)\nThere\'s somethin\' \'bout his manners (uh huh)\nHavana, ooh na-na (uh)\n\nHe didn\'t walk up with that "how you doin\'?" (uh)\nWhen he came in the room\nHe said there\'s a lot of girls I can do with (uh)\nBut I can\'t without you\nI knew him forever in a minute (hey)\nThat summer night in June\nAnd papa says he got malo in him (uh)\nHe got me feelin\' like...\n\nOoh, ooh-ooh-ooh-ooh-ooh-ooh-ooh (ayy)\nI knew it when I met him (ayy), I loved him when I left him\nGot me feelin\' like, ooh, ooh-ooh-ooh-ooh-ooh-ooh-ooh\nAnd then I had to tell him, I had to go\nOh na-na-na-na-na (woo)\n\nHavana, ooh na-na (ayy, ayy)\nHalf of my heart is in Havana, ooh na-na (ayy, ayy)\n...\n\n******* This Lyrics is NOT for Commercial use *******'

# %%
data = musixmatch.matcher_lyrics_get('Class Clown','Owsley')
data
# Out:
# {'message': {'header': {'status_code': 200, 'execute_time': 0.053925037384033},
#   'body': {'lyrics': {'lyrics_id': 4197813,
#     'can_edit': 0,
#     'locked': 0,
#     'published_status': 9,
#     'action_requested': '',
#     'verified': 0,
#     'restricted': 0,
#     'instrumental': 0,
#     'explicit': 0,
#     'lyrics_body': "Love is a friend of mine\nIt tells me to keep my head\nWhen all those around me are\nLosing theirs instead\n\nYou know me well\nI do it all on my own\nI wanted to turn around\nAnd make my house a home\n\nFor the king and the queen\n(And live in never, neverland)\nI know they're waiting for me\n...\n\n******* This Lyrics is NOT for Commercial use *******",
#     'lyrics_language': 'en',
#     'lyrics_language_description': 'English',
# ...
