# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('SongCSV.csv')

# %%
df
# Out:
#       SongNumber              SongID  AlbumID  \
# 0              1  SOQUGNH12A6D4FBB0E    64577
# 1              2  SOEEPYY12A58A7B1C8    21585
# 2              3   SOPHMRL12AB017E87   401052
# 3              4  SOPHKAI12AB018873D   818763
# 4              5  SOOWVUN12AB0185435   470991
# 5              6  SOQEKJO12AB0188E78   509775
# 6              7  SOVWTKI12A58A789B6   257644
# 7              8  SOHWHZJ12A58A79FA8   356024
# 8              9  SOLHMRA12A8C13234A   242839
# 9             10  SORURBV12A8C140200   522538
# 10            11  SOQAFSW12A67021430    14224
# 11            12  SOQENPJ12AB0180997   532011
# 12            13  SOOCZWD12AB0185147   503069
# 13            14   SOYMDLM12A6D4FB10    59445
# 14            15  SODIDOO12A58A794E4   308299
# 15            16  SOBPQVV12A8C13BE51   264107
# 16            17  SOMNXCC12AB0187BE7   589241
# 17            18  SOVQYSC12AB017D1C5   632887
# 18            19  SOLPFAE12A8C13AF2D   109835
# ...

# %%
df['ArtistName']
# Out:
# 0                                         Don Francisco
# 1                                               Daara J
# 2                                       New Found Glory
# 3                                        Mindy McCready
# 4                                      Chantal Chamandy
# 5                              Mar\xc3\xada Elena Walsh
# 6                                           Ivan Parker
# 7                                               Kaskaad
# 8                                          Joy Division
# 9                                      Sonora Santanera
# 10                                              The Jam
# 11                                            Tim Exile
# 12                                          Bad Company
# 13                                 Sir Neville Marriner
# 14                                       Phantom Planet
# 15                                  Drop Dead_ Gorgeous
# 16                                              Madonna
# ...

# %%
type(df['SongID'])
# Out:
# pandas.core.series.Series

# %%
df['SongID'].values.tolist()
# Out:
# ['SOQUGNH12A6D4FBB0E',
#  'SOEEPYY12A58A7B1C8',
#  'SOPHMRL12AB017E87',
#  'SOPHKAI12AB018873D',
#  'SOOWVUN12AB0185435',
#  'SOQEKJO12AB0188E78',
#  'SOVWTKI12A58A789B6',
#  'SOHWHZJ12A58A79FA8',
#  'SOLHMRA12A8C13234A',
#  'SORURBV12A8C140200',
#  'SOQAFSW12A67021430',
#  'SOQENPJ12AB0180997',
#  'SOOCZWD12AB0185147',
#  'SOYMDLM12A6D4FB10',
#  'SODIDOO12A58A794E4',
#  'SOBPQVV12A8C13BE51',
#  'SOMNXCC12AB0187BE7',
#  'SOVQYSC12AB017D1C5',
#  'SOLPFAE12A8C13AF2D',
#  'SOSFUQC12AB017E17E',
#  'SOHLHAI12A8C139204',
#  'SOWWOFM12A6D4F82F0',
#  'SOMNSHX12A58A79CD2',
#  'SOHCFNL12A8C140C2E',
#  'SONAEGX12A8C141C53',
#  'SOOAMWT12A8C13B479',
#  'SOLYUTF12A8C133225',
#  'SOJYYHN12AB0182966',
#  'SOASHZJ12A8C1426D8',
#  'SOYYFNE12AB018A96D',
#  'SOIRKJL12A8C13A2AA',
#  'SOLQETH12AB0181E42',
#  'SOZPMGI12AB018979F',
#  'SOZYCQM12A8C13F9A',
#  'SOXVMZV12A8C142488',
#  'SOPLYEI12AB0181C03',
#  'SOLKGAA12AB0184EF8',
#  'SOIAEVG12A8C141B2F',
#  'SOKASWV12AB01857B5',
#  'SOQFUXL12A8C136D6',
# ...

# %%
songNameList = df['Title'].values.tolist()
artistNameList = df['ArtistName'].values.tolist()
albumNameList = df['AlbumName'].values.tolist()

# %%
songNameList[0] = 'Overture (Genesis & Job)'
albumNameList[0] = albumNameList[0].replace('And', '&')
print(albumNameList[0])
albumNameList1 = '(' + albumNameList[0] + 'b)'
print(albumNameList1)
print(songNameList[0])
songNameList[0] = songNameList[0].replace(albumNameList1[0], '')
songNameList[0]
# Out:
# Genesis & Jo
# (Genesis & Job)
# Overture (Genesis & Job)
# 'Overture Genesis & Job)'

# %%
songNameList[0] = '('+songNameList[0]+')'

# %%
songNameList[0]
# Out:
# '(Overture (b))'

# %%
df = pd.read_csv('SongCSV.csv')
df.head()
# Out:
#    SongNumber              SongID  AlbumID            AlbumName  \
# 0           1  SOQUGNH12A6D4FBB0E    64577       Genesis And Jo
# 1           2  SOEEPYY12A58A7B1C8    21585            Boomerang
# 2           3   SOPHMRL12AB017E87   401052  Not Without A Fight
# 3           4  SOPHKAI12AB018873D   818763       bIm Still Here
# 4           5  SOOWVUN12AB0185435   470991               Beladi
#
#              ArtistID  ArtistLatitude    ArtistLocation  ArtistLongitude  \
# 0  ARLQ5EV1187FB4491D        38.99792          Colorado       -105.55096
# 1  ARKZNO81187FB37FBA             NaN               NaN              NaN
# 2  ARH9HS41187FB5BC6F             NaN   Coral Spring FL              NaN
# 3  ARZL6CE1187FB3F264        27.97580    Fort Meyers FL        -81.54106
# 4  AR5S26K1187B9A3141        31.19224  Alexandria Egypt         29.88987
#
#          ArtistName  Danceability   Duration  KeySignature  \
# 0     Don Francisco             0  311.22240             0
# ...
